# %%
# Simple function 

def options(x,y,z):
    print("a):", x)
    print("b):", y)
    print("c):", z)
    
    
print("Hello! Welcome to my Quiz" "\n" "All Questions carries 1 marks each")
ans = input("Are you ready to play (yes/no): ")
a ="Note: wrtie answers! do not write option."

# Setting initial score as 0
# Total questions as 4
score = 0
total_questions = 4


# setting the list of correct answers

correct_answers =["python", "steve jobs", "artificial intelligence", "bitcoin"]



if ans.lower() == "yes":
    print(a)
    print("Question- What is the best Programming Language? ")
    options("Python", "C", "Java" )
    ans=input("Answer")
    if ans.lower() == correct_answers[0]:
        score=score+1
        print("Correct")
    else:
        print("Incorrect")
    print(a)
    print("Question- Who is the Founder of Apple Inc? ")
    options("Mark Zuckerberg", "Warren Buffet", "Steve jobs")
    ans = input("Answer")
    if ans.lower() == correct_answers[1]:
        score=score+1
        print("Correct")
    else:
        print("Incorrect")
    print(a)
    print("Question- What is more better among these? ")
    options("Data Science", "Artificial Intelligence", "Digital Marketing")
    ans = input("Answer")
    if ans.lower() == correct_answers[2]:
        score=score+1
        print("Correct")
    else:
        print("Incorrect")
    print(a)
    print("Question- What is the best Investment? ")
    options("Share Capital", "Mutual Funds", "Bitcoin")
    ans = input("Answer")
    if ans.lower() == correct_answers[3]:
        score=score+1
        print("Correct")
    else:
        print("Incorrect")

        
i = score
if i < 3:
    print("oops, your score is ",i,"/ 4. Better luck next time.")
elif i == 3:
    print("wow! you scored ",i,"/ 4. You are quiet smart.")
else:
    print("Congratulations! it's a perfect ",i,"/ 4. You are Intelligent.")
# Out:
# Hello! Welcome to my Quiz
# All Questions carries 1 marks each
# Are you ready to play (yes/no): yes
# Note: wrtie answers! do not write option.
# Question- What is the best Programming Language?
# a): Python
# b): C
# c): Java
# AnswerPython
# Correct
# Note: wrtie answers! do not write option.
# Question- Who is the Founder of Apple Inc?
# a): Mark Zuckerberg
# b): Warren Buffet
# c): Steve jobs
# AnswerMark Zuckerberg
# Incorrect
# Note: wrtie answers! do not write option.
# Question- What is more better among these?
# a): Data Science
# b): Artificial Intelligence
# c): Digital Marketing
# AnswerArtificial Intelligence
# Correct
# Note: wrtie answers! do not write option.
# Question- What is the best Investment?
# a): Share Capital
# b): Mutual Funds
# c): Bitcoin
# AnswerBitcoin
# Correct
# wow! you scored  3 / 4. You are quiet smart.
